# %% [markdown]
# # 파이썬 라이브러리 : Matplotlib

# %% [markdown]
# ## 1. 라이브러리 설치하기

# %%
# !pip install matplotlib

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.__version__
# Out:
# '3.5.2'

# %% [markdown]
# ## 2.Matplotlib 그래프 사용 예

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 한글폰트 지정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 그래프 크기 지정
plt.rcParams['figure.figsize'] = (10, 6) # 인치

# 파일 불러오기
filename = 'C:/python/dataAnalysis/data/인구밀도.csv'
filename = 'data/인구밀도.csv'
df = pd.read_csv(filename, encoding='cp949')
df

X = df['행정구역별']
Y1 = df['2020']
Y2 = df['2019']

# plt.style.use('seaborn')
plt.plot(X, Y1, color ='red', linestyle='dashed', label='2020')      # 선 그래프
# plt.plot(X, Y1, 'r^-')
plt.bar(X, Y2, color='green', label='2019')     # 막대 그래프
plt.scatter(X, Y1, color='blue')  # 점 그래프
plt.xticks(rotation=45)
plt.title('행정구역별 인구수', fontsize=20)
plt.xlabel('행정구역')
plt.ylabel('인구수')
plt.legend()
plt.show()

# %% [markdown]
# #### HyperLink 그래프

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

fig = plt.figure()
s = plt.scatter([1, 2, 3], [4, 5, 6])
s.set_urls(['https://www.bbc.co.uk/news', 'https://www.google.com/', None])
fig.savefig('scatter.svg')

fig = plt.figure()
delta = 0.025
x = y = np.arange(-3.0, 3.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1 - Z2) * 2
#print(Z)

im = plt.imshow(Z, interpolation='bilinear', cmap=cm.gray,
                origin='lower', extent=[-3, 3, -3, 3])

im.set_url('https://www.google.com/')
fig.savefig('image.svg')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_11364\1253260408.py:23: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.savefig('image.svg')
# C:\python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### [실습] 날씨데이터 (선, 막대, 점)그래프로 시각화하기
# - data : weather_total.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/weather_total.csv', encoding='cp949')
del df['Unnamed: 0']
df
# Out:
#               일시  평균기온(°C)  평균 상대습도(%)  평균 전운량(1/10)  합계 일조 시간(hr)  \
# 0     2010-01-01      -7.6        48.0           3.8           7.3
# 1     2010-01-02      -3.6        76.4           6.0           0.8
# 2     2010-01-03      -6.8        49.3           2.6           8.2
# 3     2010-01-04      -5.9        84.1           7.5           0.1
# 4     2010-01-05      -9.9        66.4           2.1           7.5
# ...          ...       ...         ...           ...           ...
# 4013  2020-12-27       5.8        62.9           7.5           NaN
# 4014  2020-12-28       6.7        72.1           5.3           NaN
# 4015  2020-12-29       0.1        70.8           8.5           NaN
# 4016  2020-12-30     -10.9        55.5           0.8           NaN
# 4017  2020-12-31      -8.9        53.9           0.4           NaN
#
#       강수 계속시간(hr)  구분
# 0             NaN   0
# 1            6.57   1
# 2             NaN   0
# 3           13.03   1
# 4            0.95   1
# ...

# %%
plt.rcParams['axes.unicode_minus'] = False

X = df.일시
Y1 = df['평균기온(°C)']
# Y2 = df['평균 상대습도(%)']

plt.plot(X, Y1)
# plt.bar(X, Y2)
plt.title('일자별 날씨 현황')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 한글폰트 지정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 그래프 크기 지정
plt.rcParams['figure.figsize'] = (10, 6) # 인치

# 파일 불러오기
filename = 'C:/python/dataAnalysis/data/인구밀도.csv'
filename = 'data/인구밀도.csv'
df = pd.read_csv(filename, encoding='cp949')
df

X = df['행정구역별']
Y1 = df['2020']
Y2 = df['2019']

plt.bar(X, Y2, zorder=1, label='2019', color='red')
plt.bar(X, Y1, zorder=2, label='2020')
plt.legend()
plt.show()

# %% [markdown]
# ### Pie그래프

# %%
# label = df['행정구역별'].to_list()
print(label)

plt.pie(Y1, autopct='%1.1f%%',
       textprops={'color':'r'},
       labels=df['행정구역별'])

plt.savefig('image/pie.jpg')

plt.show()
# Out:
# ['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시', '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도', '제주도']
