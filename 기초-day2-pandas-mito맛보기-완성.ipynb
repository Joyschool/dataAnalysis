# %% [markdown]
# ## [실습] Mito를 이용한 Spreadsheet 맛보기

# %% [markdown]
# ### Doc : https://docs.trymito.io/
#
# https://docs.trymito.io/how-to/creating-a-mitosheet

# %% [markdown]
# ### 라이브러리 설치하기
#
# #### 인스톨러 다운로드

# %%
# !python -m pip install mitoinstaller
# Out:
# Requirement already satisfied: mitoinstaller in c:\python\python39\lib\site-packages (0.0.166)
# Requirement already satisfied: colorama in c:\python\python39\lib\site-packages (from mitoinstaller) (0.4.5)
# Requirement already satisfied: termcolor in c:\python\python39\lib\site-packages (from mitoinstaller) (1.1.0)
# Requirement already satisfied: analytics-python in c:\python\python39\lib\site-packages (from mitoinstaller) (1.4.0)
# Requirement already satisfied: python-dateutil>2.1 in c:\python\python39\lib\site-packages (from analytics-python->mitoinstaller) (2.8.2)
# Requirement already satisfied: monotonic>=1.5 in c:\python\python39\lib\site-packages (from analytics-python->mitoinstaller) (1.6)
# Requirement already satisfied: backoff==1.10.0 in c:\python\python39\lib\site-packages (from analytics-python->mitoinstaller) (1.10.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\python\python39\lib\site-packages (from analytics-python->mitoinstaller) (2.28.1)
# Requirement already satisfied: six>=1.5 in c:\python\python39\lib\site-packages (from analytics-python->mitoinstaller) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python39\lib\site-packages (from requests<3.0,>=2.7->analytics-python->mitoinstaller) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python\python39\lib\site-packages (from requests<3.0,>=2.7->analytics-python->mitoinstaller) (1.26.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\python\python39\lib\site-packages (from requests<3.0,>=2.7->analytics-python->mitoinstaller) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python39\lib\site-packages (from requests<3.0,>=2.7->analytics-python->mitoinstaller) (2022.6.15)

# %% [markdown]
# #### 인스톨러 설치하기 [주의!] (PC 명령프롬프트 창에서 실행시킨다.)

# %%
python -m mitoinstaller install
# Out:
# ^C

# %% [markdown]
# ### mito 사용하기
# - python -m mitoinstaller install  명령어를 실행시키면 뜨는 주피터 노트북 창에서만 코드 실행 가능하다

# %%
import mitosheet
mitosheet.sheet()
# mitosheet.sheet(analysis_to_replay="id-xfxdrmlqcu")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-mkrjjdsfnb", "analysisToReplay": null, "code": [], "stepSu…
